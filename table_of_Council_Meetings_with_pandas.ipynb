# %% [markdown]
# <a href="https://colab.research.google.com/github/KILjungjoon/Project_Asian_Parliament/blob/main/table_of_Council_Meetings_with_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install BeautifulSoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import pandas as pd

# %%
url = 'http://www.legco.gov.hk/yr16-17/english/counmtg/question/ques1617.htm#toptbl'
url
# Out:
# 'http://www.legco.gov.hk/yr16-17/english/counmtg/question/ques1617.htm#toptbl'

# %%
df=pd.read_html(url)
df
# Out:
# [    0                 1
#  0 NaN  Year 2020 - 2021
#  1 NaN  Year 2019 - 2020
#  2 NaN  Year 2018 - 2019
#  3 NaN  Year 2017 - 2018
#  4 NaN  Year 2016 - 2017,
#      0                                                  1
#  0 NaN  Questions(Year 2016 - 2017) To view the wordin...,
#                 0                                                  1  \
#  0   October 2016  12*Legend symbol denoting No oral or written q...
#  1  November 2016                                                  2
#  2  December 2016                                              7 & 8
#  3   January 2017                                            11 & 12
#  4  February 2017                                              8 & 9
#  5     March 2017                                              1 & 2
#  6     April 2017  12 & 13+Legend symbol denoting Only written qu...
#  7       May 2017                                            10 & 11
#  8      June 2017  1*Legend symbol denoting No oral or written qu...
# ...

# %%
len(df)
# Out:
# 32

# %%
df[2]
# Out:
#                0                                                  1  \
# 0   October 2016  12*Legend symbol denoting No oral or written q...
# 1  November 2016                                                  2
# 2  December 2016                                              7 & 8
# 3   January 2017                                            11 & 12
# 4  February 2017                                              8 & 9
# 5     March 2017                                              1 & 2
# 6     April 2017  12 & 13+Legend symbol denoting Only written qu...
# 7       May 2017                                            10 & 11
# 8      June 2017  1*Legend symbol denoting No oral or written qu...
# 9      July 2017  5*Legend symbol denoting No oral or written qu...
#
#                                                    2  \
# 0                                                 19
# 1                                             9 & 10
# 2                                            14 & 15
# ...

# %%
df[4]
# Out:
#       Question No.              Raised by  \
# 0       Q. 1(Oral)       Hon HUI Chi-fung
# 1       Q. 2(Oral)      Hon Mrs Regina IP
# 2       Q. 3(Oral)       Hon MA Fung-kwok
# 3       Q. 4(Oral)    Hon LEUNG Yiu-chung
# 4       Q. 5(Oral)           Hon Paul TSE
# 5       Q. 6(Oral)  Dr Hon Elizabeth QUAT
# 6    Q. 7(Written)         Hon Tanya CHAN
# 7    Q. 8(Written)       Hon Frankie YICK
# 8    Q. 9(Written)       Hon CHAN Hak-kan
# 9   Q. 10(Written)         Hon WU Chi-wai
# 10  Q. 11(Written)        Hon IP Kin-yuen
# 11  Q. 12(Written)          Hon Alice MAK
# 12  Q. 13(Written)      Hon Kenneth LEUNG
# 13  Q. 14(Written)  Hon Charles Peter MOK
# 14  Q. 15(Written)       Hon Sixtus LEUNG
# 15  Q. 16(Written)      Hon WONG Kwok-kin
# 16  Q. 17(Written)     Hon KWOK Wai-keung
# 17  Q. 18(Written)          Hon Eddie CHU
# 18  Q. 19(Written)  Dr Hon Elizabeth QUAT
# 19  Q. 20(Written)           Hon Paul TSE
# 20  Q. 21(Written)       Hon Frankie YICK
# ...

# %%
df[-1]
# Out:
#       Question No.               Raised by  \
# 0       Q. 1(Oral)            Hon James TO
# 1       Q. 2(Oral)       Hon Kenneth LEUNG
# 2       Q. 3(Oral)          Hon Tanya CHAN
# 3       Q. 4(Oral)            Hon Paul TSE
# 4       Q. 5(Oral)       Hon Mrs Regina IP
# 5       Q. 6(Oral)  Dr Hon Priscilla LEUNG
# 6    Q. 7(Written)          Hon Jeremy TAM
# 7    Q. 8(Written)        Hon YUNG Hoi-yan
# 8    Q. 9(Written)          Hon Claudia MO
# 9   Q. 10(Written)         Hon SHIU Ka-fai
# 10  Q. 11(Written)         Hon HO Kai-ming
# 11  Q. 12(Written)        Hon CHAN Han-pan
# 12  Q. 13(Written)  Dr Hon Fernando CHEUNG
# 13  Q. 14(Written)        Hon CHAN Kin-por
# 14  Q. 15(Written)         Hon IP Kin-yuen
# 15  Q. 16(Written)      Hon KWOK Wai-keung
# 16  Q. 17(Written)           Hon Alice MAK
# 17  Q. 18(Written)        Hon Frankie YICK
# 18  Q. 19(Written)          Hon Andrew WAN
# 19  Q. 20(Written)      Dr Hon Pierre CHAN
# 20  Q. 21(Written)            Hon Jimmy NG
# ...

# %% [markdown]
# # 미팅 콘텐츠도 table 형식으로 되어 있다.
# * 다만, 의원의 질문은 beautifulsoup으로 parcing을 해야 한다.

# %%
url = 'https://www.legco.gov.hk/yr16-17/english/counmtg/agenda/cm20161019.htm#questions'
url
# Out:
# 'https://www.legco.gov.hk/yr16-17/english/counmtg/agenda/cm20161019.htm#questions'

# %%
df=pd.read_html(url)
df
# Out:
# [   Subsidiary Legislation / Instruments  \
#  0                                   1.0
#  1                                   2.0
#
#                Subsidiary Legislation / Instruments.1  L.N. No.
#  0  Human Reproductive Technology (Amendment) Ordi...  155/2016
#  1  Mandatory Provident Fund Schemes (Amendment) O...  156/2016  ,
#                                                      0  \
#  0                                                  1.
#  1   (to be presented by Secretary for Food and Hea...
#  2                                                  2.
#  3   (to be presented by Secretary for Food and Hea...
#  4                                                  3.
#  5   (to be presented by Secretary for Food and Hea...
#  6                                                  4.
#  7   (to be presented by Secretary for Food and Hea...
#  8                                                  5.
#  9   (to be presented by Secretary for Labour and W...
# ...

# %%
len(df)
# Out:
# 31

# %%
# df[2]부터는 의원의 Question 내부의 테이블이다.
df[2].head()
# Out:
#      0                                                  1
# 0  (1)  of the total number of polling stations which ...
# 1  (2)  as it is stipulated in the legislation that a ...
# 2  (3)  of the number of polling stations at which the...

# %%
df[-3]
# Out:
#       0                                                  1  \
# 0   1.0  Proposed resolution under section 34(4) of the...
# 1   2.0  Motion under the Legislative Council (Powers a...
# 2   3.0  Abolishing the Mandatory Provident Fund offset...
# 3   NaN                                                (i)
# 4   NaN                                               (ii)
# 5   NaN                                              (iii)
# 6   NaN                                               (iv)
# 7   NaN                                                (v)
# 8   NaN                                               (vi)
# 9   NaN  Public Officers to attend:Secretary for Labour...
# 10  4.0  Requiring the teaching of Chinese history as a...
# 11  NaN                                                (i)
# 12  NaN                                               (ii)
# 13  NaN                                              (iii)
# 14  NaN                                               (iv)
# ...
